# %%
import pandas as pd
import numpy as np

df = pd.read_csv("2D_Data.csv")
x1 = list(df['X1'])
x2 = list(df['X2'])
X = np.ones([1000,2])
X[:,0] = x1
X[:,1] = x2
y = list(df['Y'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import datasets
from sklearn.datasets import make_classification

''''
#Data Generator
sample_size = 10
n_ft = 2
X, y = datasets.make_blobs(n_samples=sample_size, centers=2, n_features=n_ft, center_box=(0, 10))
#print(X)'''


'''plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'g^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.show()'''

plt.scatter(X[:,0], X[:,1])
plt.show()

def step(z):
    return 1 if z>0 else 0

def draw_2d(X, y, theta, intercept):
    b = -(intercept / theta[1])
    m = -(theta[0] / theta[1])
    x0 = np.linspace(0,15,100)
    y0 = m * x0 + b
    plt.plot(x0,y0)
    plt.scatter(X[:,1], X[:,2])
    #plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'g^')
    #plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
    plt.show()

def perceptron(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = [0,0,0]
    for i in range(3):
        weights[i] = np.random.randint(15,20)
    lr = 0.1
    
    for i in range(69):
        j = np.random.randint(0,10)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        if(X.shape[1] == 3):
            draw_2d(X, y, weights[1:], weights[0])
            plt.pause(0.004)
    return weights[0],weights[1:]



intercept, theta = perceptron(X, y)
# if(X.shape[1] == 2):
#     draw_2d(X, y, theta, intercept)
